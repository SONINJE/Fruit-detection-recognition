# %% [markdown]
# <a href="https://colab.research.google.com/github/SONINJE/Fruit-detection-recognition/blob/main/Fruit_detection_%26_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ''' Fruit_classifier'''

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/Yolov3
# Out:
# /content/drive/MyDrive/Colab Notebooks/Yolov3

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Yolov3'

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import csv
import glob
import keras,os
import cv2 as cv



from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator

# %%
import pathlib

data_dir = './fruit'

data_dir = pathlib.Path(data_dir)

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 300

# %%
train = list(data_dir.glob('train/*'))
PIL.Image.open(str(train[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x797 at 0x7F45E1472610>

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  image_size=(256, 256),
  seed = 1,
  batch_size=240)
# Out:
# Found 300 files belonging to 2 classes.
# Using 240 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=1,
  image_size=(255, 255),
  batch_size=240)
# Out:
# Found 300 files belonging to 2 classes.
# Using 60 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['test', 'train']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
